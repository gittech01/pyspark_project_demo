# %%
from pyspark.sql import SparkSession
from pyspark.sql.dataframe import DataFrame

from normalize_json import NormalizeJSON

# %%
def sparkSession(name_app: str, core_limit: int = None) -> SparkSession:
    
    core = '*' if not core_limit else core_limit
    
    spark = (
        SparkSession
        .builder
        .master(f'local[{core}]')
        .appName(name_app)
        .getOrCreate()
    )
    return spark

# %%
def read_files(file_name: str) -> list:
    import glob
    
    files = glob.glob(f"{file_name}.json")
    return files

# %%
def read_files_json_spark(spark_session: SparkSession, path_file: list | str) -> list[DataFrame]:
    list_spark_frames: list = []

    path_files = [path_file] if not isinstance(path_file, list) else path_file

    for path in path_files:
        frame = spark_session.read.option("multiline","true").json(path)
        list_spark_frames.append(frame)

    return list_spark_frames

# %%
spark_session = sparkSession("Teste", core_limit=2)
# Out:
# 25/07/07 20:24:28 WARN Utils: Your hostname, edsojor resolves to a loopback address: 127.0.1.1; using 192.168.15.10 instead (on interface wlo1)
# 25/07/07 20:24:28 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/07/07 20:24:29 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/07/07 20:24:30 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
list_files = read_files(file_name='metrics')
list_dataframe = read_files_json_spark(spark_session=spark_session, path_file=list_files)
list_dataframe[0].show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{2025-04-24 21:55:01.352000+00:00, 2025-04-24 22:08:57.287000+00:00, c6620a8f-bb4d-4212-9363-ae3251cf8dc8, 2025-04-24 21:48:57.411000+00:00, [e2345938-2a57-41cd-af2f-11e53ce634e0], 3.418089186880809, 91.76698303222656, outbound, [{a5dc33e4-f752-4906-8acb-eade59b49b76, [{NULL, NULL, sip:5fb6b9638ea488199a48b074+itautestdrive.orgspan.comglocalhost, NULL, [{[audio/opus], 2025-04-24 21:55:01.377000+00:00, NULL}], [{2025-04-24 21:49:00.127000+00:00, tContacting, 2716}], [{2025-04-24 21:49:00.127000+00:00, 2025-04-24 21:48:57.411000+00:00}]}], 52a392c2-728d-4be4-af32-365692ab8f8f}, {a5dc33e4-f752-4906-5968-eade59b49b76, [{NULL, NULL, sip:5fb6b9638ea488199a48b074+itautestdrive.orgspan.comglocalhost, NULL, [{[audio/opus], 2025-04-24 21:57:01.377000+00:00, NULL}], [{2025-04-24 21:39:00.127000+00:00, tContacting, 2716}], [{2025-04-24 21:49:00.127000+00:00, 2025-04-24 21:48:57.411000+00:00}]}], 52a392c2-728d-4be4-af32-365692ab8f8f}]}]|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
normalize_json = NormalizeJSON(separator='_', max_depth=10)

# %%
df1= normalize_json.flatten(list_dataframe[0])

# %%
df1.show(truncate=False)
# Out:
# +--------------------------------+--------------------------------+------------------------------------+--------------------------------+-------------------------------------+------------------------------------------+--------------------------+------------------------------------+------------------------------------+------------------------------------+-------------------------------------------+--------------------------------------+----------------------------------------------------------------+-------------------------------+----------------------------------------------------------+---------------------------------------------------------------+--------------------------------------------+---------------------------------------+----------------------------------------+-----------------------------------------------+-------------------------------------------------+------------------------------------------------------+
# |data_conference_start           |data_conversation_end           |data_conversation_id                |data_conversation_start         |data_media_stats_min_conversation_mos|data_media_stats_min_conversation_r_factor|data_originating_direction|data_division_ids                   |data_participants_participant_id    |data_participants_user_id           |data_participants_sessions_active_skill_ids|data_participants_sessions_acw_skipped|data_participants_sessions_ani                                  |data_participants_sessions_flow|data_participants_sessions_media_endpoint_stats_event_time|data_participants_sessions_media_endpoint_stats_invalid_packets|data_participants_sessions_metrics_emit_date|data_participants_sessions_metrics_name|data_participants_sessions_metrics_value|data_participants_sessions_segments_segment_end|data_participants_sessions_segments_segment_start|data_participants_sessions_media_endpoint_stats_codecs|
# +--------------------------------+--------------------------------+------------------------------------+--------------------------------+-------------------------------------+------------------------------------------+--------------------------+------------------------------------+------------------------------------+------------------------------------+-------------------------------------------+--------------------------------------+----------------------------------------------------------------+-------------------------------+----------------------------------------------------------+---------------------------------------------------------------+--------------------------------------------+---------------------------------------+----------------------------------------+-----------------------------------------------+-------------------------------------------------+------------------------------------------------------+
# |2025-04-24 21:55:01.352000+00:00|2025-04-24 22:08:57.287000+00:00|c6620a8f-bb4d-4212-9363-ae3251cf8dc8|2025-04-24 21:48:57.411000+00:00|3.418089186880809                    |91.76698303222656                         |outbound                  |e2345938-2a57-41cd-af2f-11e53ce634e0|a5dc33e4-f752-4906-8acb-eade59b49b76|52a392c2-728d-4be4-af32-365692ab8f8f|NULL                                       |NULL                                  |sip:5fb6b9638ea488199a48b074+itautestdrive.orgspan.comglocalhost|NULL                           |2025-04-24 21:55:01.377000+00:00                          |NULL                                                           |2025-04-24 21:49:00.127000+00:00            |tContacting                            |2716                                    |2025-04-24 21:49:00.127000+00:00               |2025-04-24 21:48:57.411000+00:00                 |audio/opus                                            |
# |2025-04-24 21:55:01.352000+00:00|2025-04-24 22:08:57.287000+00:00|c6620a8f-bb4d-4212-9363-ae3251cf8dc8|2025-04-24 21:48:57.411000+00:00|3.418089186880809                    |91.76698303222656                         |outbound                  |e2345938-2a57-41cd-af2f-11e53ce634e0|a5dc33e4-f752-4906-5968-eade59b49b76|52a392c2-728d-4be4-af32-365692ab8f8f|NULL                                       |NULL                                  |sip:5fb6b9638ea488199a48b074+itautestdrive.orgspan.comglocalhost|NULL                           |2025-04-24 21:57:01.377000+00:00                          |NULL                                                           |2025-04-24 21:39:00.127000+00:00            |tContacting                            |2716                                    |2025-04-24 21:49:00.127000+00:00               |2025-04-24 21:48:57.411000+00:00                 |audio/opus                                            |
# +--------------------------------+--------------------------------+------------------------------------+--------------------------------+-------------------------------------+------------------------------------------+--------------------------+------------------------------------+------------------------------------+------------------------------------+-------------------------------------------+--------------------------------------+----------------------------------------------------------------+-------------------------------+----------------------------------------------------------+---------------------------------------------------------------+--------------------------------------------+---------------------------------------+----------------------------------------+-----------------------------------------------+-------------------------------------------------+------------------------------------------------------+
